# %% [markdown]
# <a href="https://colab.research.google.com/github/hby1117/class2026Spring/blob/main/03_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics

# %% [markdown]
# ## 1. Flow
# 1. if
# 2. for
# 3. while

# %% [markdown]
# ### If
# ```python
# # Compare
# a == b
# a != b
# a > b
# a >= b
# a < b
# a <= b
# ```
# ```python
# # Logical Operation
# a and b
# a or b
# not a
# ```
# ```python
# # Syntax
# if condition:
#   # execute this code block
# elif another_condition:
#   # execute this code block
# else:
#   # execute this code block
# ```

# %% [markdown]
# ### For
# ```python
# # Syntax
# for item in sequence:
# 	# execute this code block for each item
# ```

# %% [markdown]
# ### While
# ```python
# # Syntax
# while condition:
# 	# execute this code block as long as the condition is true
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Function
# ```python
# # Define
# def function_name(parameters):
#   # Code block
#   return result
# ```
# ```python
# # Call
# output_data = function_name(input_data)

# %% [markdown]
# ```python
# # Function scope
# global_var = "global"
#
# def custom_func():
# 	local_var = "local"
# 	print(global_var)
# 	print(local_var)
#
# custom_func()
# print(global_var)
# print(local_var)  # This raises an error
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Exercises

# %% [markdown]
# 1
# <br />
# <br />
# Jane is 16 years old and is 153cm tall.
# <br>
# Check if Jane can ride a roller coaster.
# <br />
# <br />
# To ride a roller coaster,
# <br />
# one should meet all these conditions:
#
# 1. over 150cm
# 2. over 15 years old

# %% [markdown]
# 2
# <br />
# <br />
# Print a greeting message to each friend using `for` loop.
# <br />
# Do not forget to call each friend's name!
# <br />
# <br />
# ```python
# friends = ["Mia", "Liam", "Jay"]
# ```

# %% [markdown]
# 3
# <br />
# <br />
# From 1 to 10, print even numbers only.

# %% [markdown]
# 4
# <br />
# <br />
# You are filling a water bottle using a machine.
# <br />
# Each time you press a button, the machine adds 100 ml of water.
# <br />
# Your bottle can hold 1000 ml.
# <br />
# Write a while loop that keeps adding water until the bottle is full.

# %% [markdown]
# 5
# <br />
# <br />
# Define a function that takes a temperature in Farenheit and returns it in Celsius.
# <br />
# <br />
# $C = \frac{5}{9}(F - 32)$
