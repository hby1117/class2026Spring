# %% [markdown]
# <a href="https://colab.research.google.com/github/hby1117/class2026Spring/blob/main/05_Text_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Data Analysis (Simple)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv("alice.csv")

# %% [markdown]
# ## 2. Convert Text to Words

# %%
df["Words"] = df["Text"].str.lower().str.split()

# %% [markdown]
# ## 3. Count Words

# %%
df["WordCount"] = df["Words"].apply(len)

# %% [markdown]
# ## 4. Group Analysis

# %%
total_result = df.groupby("Book")["WordCount"].sum()
mean_result = df.groupby("Book")["WordCount"].mean()
max_result = df.groupby("Book")["WordCount"].max()
min_result = df.groupby("Book")["WordCount"].min()

# %% [markdown]
# ## 5. Visualization

# %%
total_result.plot(kind='bar')
plt.title('Mean Word Count')
plt.show()

# %%
mean_result.plot(kind='bar')
plt.title('Mean Word Count')
plt.show()

# %%
max_result.plot(kind='bar')
plt.title('Mean Word Count')
plt.show()

# %%
min_result.plot(kind='bar')
plt.title('Mean Word Count')
plt.show()

# %% [markdown]
# ## 6. Filtering

# %%
df[df['WordCount'] > 2500]
