# %% [markdown]
# <a href="https://colab.research.google.com/github/hby1117/class2026Spring/blob/main/04_Packages & Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packages & Pandas

# %% [markdown]
# ## 1. Packages
#
# ```python
# import random
#
# print(random.randint(1, 9))
# ```
#
# ```python
# import math
#
# print(math.sqrt(16))
# print(math.pi)
# ```

# %% [markdown]
# ## 2. Pandas
#
# ```python
# import pandas as pd
#
# a = pd.read_csv("weather.csv")
# b = pd.DataFrame([{"Column1": "A", "Column2": 1000}, {"Column1": "B", "Column2": 300}])
# ```
# ```python
# # Access by column
# c = a["Temperature"]
# d = a[["Humidity", "City"]]
#
# # Access by row
# e = a.loc[0]
# f = a.loc[1:2]
#
# # Access specific value
# g = a.loc[0, "Temperature"]
# h = a.loc[1:2, ["Humidity", "City"]]
# ```

# %% [markdown]
# ```python
# # Modify
# a.loc[5] = { "Temperature": 19, "Humidity": 28, "City": "Seoul" }
# ```

# %% [markdown]
# ```python
# # Delete by column
# a = a.drop("Temperature", axis=1)
#
# # Delete by row
# a = a.drop(5, axis=0)
# ```

# %% [markdown]
# ```python
# # Operations on column
# a.Quantity + 2
# a.Quantity > 60
# ```
